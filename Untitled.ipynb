# %%
import pandas as pd

# %%
df = pd.read_csv('vehicles_us.csv')
df
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1      25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2       5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3       1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4      14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# ...      ...         ...             ...        ...        ...  ...       ...
# 51520   9249      2013.0   nissan maxima   like new        6.0  gas   88136.0
# 51521   2700      2002.0     honda civic    salvage        4.0  gas  181500.0
# 51522   3950      2009.0  hyundai sonata  excellent        4.0  gas  128000.0
# 51523   7455      2013.0  toyota corolla       good        4.0  gas  139573.0
# 51524   6300      2014.0   nissan altima       good        4.0  gas       NaN
#
# ...

# %%
df['cylinders'].unique()
# Out:
# array([ 6.,  4.,  8., nan,  5., 10.,  3., 12.])

# %%
cylinders_null_by_model = df[df['cylinders'].isnull()].groupby('model')
cylinders_null_by_model.head()
# Out:
#        price  model_year                              model  condition  \
# 9       9200      2008.0                        honda pilot  excellent
# 36     10499      2013.0                       chrysler 300       good
# 37      7500      2005.0                      toyota tacoma       good
# 59      5200      2006.0                  toyota highlander       good
# 63     30000      1966.0                       ford mustang  excellent
# ...      ...         ...                                ...        ...
# 20653  21900      2008.0         chevrolet silverado 3500hd  excellent
# 21013  21990         NaN         chevrolet silverado 3500hd       good
# 21752  33765      2014.0         chevrolet silverado 3500hd  excellent
# 21779  14999      2012.0                             bmw x5  excellent
# 25982  34900         NaN  mercedes-benz benze sprinter 2500  excellent
#
#        cylinders    fuel  odometer transmission         type paint_color  \
# ...

# %%
model_cyli = pd.DataFrame(df.groupby(['model','cylinders']).size())
model_cyli
# Out:
#                                0
# model             cylinders
# acura tl          4.0          3
#                   6.0        208
# bmw x5            6.0        200
#                   8.0         51
# buick enclave     4.0          1
# ...                          ...
# volkswagen jetta  5.0        123
#                   6.0          4
# volkswagen passat 4.0        243
#                   5.0         43
#                   6.0         30
#
# [307 rows x 1 columns]

# %%
for x in df['cylinders']:
    if df['cylinders'].isnull() == True:
        print(x)
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-e2b5b776c47d> in <module>
#       1 for x in df['cylinders']:
# ----> 2     if df['cylinders'].isnull() == True:
#       3         print(x)
#       4     else:
#       5         pass
#
# ~/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df['cylinders'] = df['cylinders'].fillna(
# Out:
#   File "<ipython-input-32-3713e2768e4e>", line 1
#     df['cylinders'] = df['cylinders'].fillna(lambda x: x df_grouped)
#                                                          ^
# SyntaxError: invalid syntax

# %%
df['cylinders'].unique()
# Out:
# array([ 6.,  4.,  8., nan,  5., 10.,  3., 12.])

# %%
df_grouped = df.groupby('model')['cylinders'].median()
df_grouped
# Out:
# model
# acura tl             6.0
# bmw x5               6.0
# buick enclave        6.0
# cadillac escalade    8.0
# chevrolet camaro     6.0
#                     ...
# toyota sienna        6.0
# toyota tacoma        6.0
# toyota tundra        8.0
# volkswagen jetta     4.0
# volkswagen passat    4.0
# Name: cylinders, Length: 100, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7c0763eb709a> in <module>
# ----> 1 df.groupby('model')['cylinders'].fillna(x.mode()[0])
#
# NameError: name 'x' is not defined

# %%
df['cylinders'] = df['cylinders'].fillna(df.groupby('model')['cylinders'].apply(lambda x: x.fillna(x.mode()[0])))

# %%
df['cylinders'].unique()
# Out:
# array([ 6.,  4.,  8.,  5., 10.,  3., 12.])

# %%
df.groupby('cylinders').sum()
# Out:
#                price  model_year      odometer   is_4wd  days_listed
# cylinders
# 3.0           291445     66404.0  2.794072e+06      6.0         1566
# 4.0        109379950  25854059.0  1.245578e+09   2964.0       545851
# 5.0          1795993    498324.0  2.790012e+07     76.0        10451
# 6.0        194709869  29440446.0  1.534222e+09   8144.0       620785
# 8.0        251623467  29533938.0  1.677432e+09  11365.0       629890
# 10.0         3973247   1040638.0  3.513718e+07    436.0        21998
# 12.0           38000      4005.0  1.675000e+05      2.0           46
